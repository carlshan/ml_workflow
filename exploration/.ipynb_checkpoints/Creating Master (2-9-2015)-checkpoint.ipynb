# %%
import pandas as pd

# %%
datapath = '/Users/liyan/Dropbox (Personal)/Updated Data 6-13 graders plus High Priority/'
address_history = pd.read_table(datapath + 'Student_Address_History 6-13 thru 1314.txt')
demographic_attendance = pd.read_table(datapath + 'Student_Demographic_Attendance plus specials 6-13 thru 1314.txt')
yearly_gpa = pd.read_table(datapath + 'Student_GPA_YearlySummary 6-13 Thru 1314.txt')

# %%
len(set(address_history['External_Student_ID']))
# Out:
# 35385

# %%
len(set(demographic_attendance['External_Student_ID']))
# Out:
# 34162

# %%
len(set(yearly_gpa['External_Student_ID']))
# Out:
# 28806

# %%
all_student_ids = list(set(address_history['External_Student_ID']).union(
                            set(demographic_attendance['External_Student_ID']).union(
                            set(yearly_gpa['External_Student_ID']))))

# %%
list(demographic_attendance.columns)
# Out:
# ['ReportingYear',
#  'SchoolYear',
#  'External_Student_ID',
#  'school_code',
#  'grade',
#  'ethnic',
#  'sex',
#  'swd',
#  'eds',
#  'lep',
#  'daysabs',
#  'exc_abs',
#  'unexc_abs',
#  'times_tardy',
#  'FirstEntryDate',
#  'LastExitDate',
#  'FirstEntry_ReportingYear',
#  'LastExit_ReportingYear',
#  'FirstEntry_Grade',
#  'LastEntry_Grade',
#  'Transferred_Before_EOY',
#  'Grade_repeats',
#  'RepeatedGrades',
#  'RepeatedYears',
#  'TransOut_Before_Grade12_Year',
#  'g8year',
#  'graduate',
#  'grad_year',
#  'Expected_GradYear',
#  'Grad_4yr']

# %%
data = pd.DataFrame(data={'External_Student_ID': all_student_ids})

# %%
data.head()
# Out:
#    External_Student_ID
# 0                 1000
# 1                 1001
# 2                 1002
# 3                 1003
# 4                 1004

# %%
list(demographic_attendance.columns)
# Out:
# ['ReportingYear',
#  'SchoolYear',
#  'External_Student_ID',
#  'school_code',
#  'grade',
#  'ethnic',
#  'sex',
#  'swd',
#  'eds',
#  'lep',
#  'daysabs',
#  'exc_abs',
#  'unexc_abs',
#  'times_tardy',
#  'FirstEntryDate',
#  'LastExitDate',
#  'FirstEntry_ReportingYear',
#  'LastExit_ReportingYear',
#  'FirstEntry_Grade',
#  'LastEntry_Grade',
#  'Transferred_Before_EOY',
#  'Grade_repeats',
#  'RepeatedGrades',
#  'RepeatedYears',
#  'TransOut_Before_Grade12_Year',
#  'g8year',
#  'graduate',
#  'grad_year',
#  'Expected_GradYear',
#  'Grad_4yr']

# %%
# these are all the variables that are static across years, so I can just merge them onto the data now
df = demographic_attendance[['FirstEntryDate',
                       'External_Student_ID',
                         'LastExitDate',
                         'FirstEntry_ReportingYear',
                         'LastExit_ReportingYear',
                         'FirstEntry_Grade',
                         'LastEntry_Grade',
                         'Transferred_Before_EOY',
                         'Grade_repeats',
                         'RepeatedGrades',
                         'RepeatedYears',
                         'TransOut_Before_Grade12_Year',
                         'g8year',
                         'graduate',
                         'grad_year',
                         'Expected_GradYear',
                         'Grad_4yr']].drop_duplicates()

# %%
df.shape
# Out:
# (34162, 17)

# %%
data = data.merge(df, on='External_Student_ID', how='left')

# %%
def merge_data_by_years(to_merge, data, reporting_year, how='left'):
    """
    Generalized version of merging each particular df
    """
    groups = to_merge.groupby(reporting_year).groups
    for group, rows in groups.iteritems():
        temp = to_merge.ix[rows].drop([reporting_year], axis=1)
        temp.rename(columns={col: col + '_' + str(group) for col in temp.columns},
                    inplace=True) # appends school year to each col
        data = data.merge(temp, left_on='External_Student_ID', 
                          right_on = 'External_Student_ID_' + str(group), 
                          how=how)
        data.drop('External_Student_ID_' + str(group), axis=1, inplace=True)
    return data

# %%
data.shape
# Out:
# (35435, 17)

# %%
# ~ 3,000 students are double or triple entered during the same year for 
# demographic attendance and the address history data
# Options: (1) take the last one (we could be missing data from earlier)
# (2) take the sum on the integer columns (but we may be inflating on 
# certain variables e.g., times_tardy and exc_abs seem to be totals
# and not recorded per semester. It's not clear how reporting practices
# work.)
# I'm going to go with (1) for now because I don't think it's worth the time
# and I've been told that you these should be entered during the end of the 
# year

# %%
deduped_add_hist = address_history.drop_duplicates(['External_Student_ID', 'ReportingYear'],
                                                   take_last=True)

# %%
include_cols = ['ReportingYear',
 'External_Student_ID',
 'Street',
 'CITY',
 'STATE',
 'ZIP',]
# Out:
# ['ReportingYear',
#  'External_Student_ID',
#  'Street',
#  'CITY',
#  'STATE',
#  'ZIP',
#  'Grade']

# %%
merged = merge_data_by_years(deduped_add_hist, data, 'ReportingYear')

# %%
print merged.shape
# Out:
# (35435, 36)

# %%
deduplicated_demog_attend = demographic_attendance.drop_duplicates(['External_Student_ID', 'ReportingYear'],
                                       take_last=True)

# %%
include_cols = ['ReportingYear',
 'External_Student_ID',
 'school_code',
 'grade',
 'ethnic',
 'sex',
 'swd',
 'eds',
 'lep',
 'daysabs',
 'exc_abs',
 'unexc_abs',
 'times_tardy',]

# %%
merged = merge_data_by_years(deduplicated_demog_attend[include_cols], merged, 'ReportingYear')

# %%
print merged.shape
# Out:
# (35435, 232)

# %%
merged = merge_data_by_years(yearly_gpa, merged, 'ReportingYear')

# %%
print merged.shape
# Out:
# (35435, 344)

# %%
merged.head()
# Out:
#    External_Student_ID             Street_2008 CITY_2008 STATE_2008 ZIP_2008  \
# 0                 1000      167 Eastover Dr SE   Concord         NC    28025
# 1                 1001      167 Eastover Dr SE   Concord         NC    28025
# 2                 1002                     NaN       NaN        NaN      NaN
# 3                 1003  4314 Concord Pointe LN   Concord         NC    28027
# 4                 1004        948 Tartan Ln Nw   Concord         NC    28027
#
#    Grade_2008             Street_2009   CITY_2009 STATE_2009 ZIP_2009  \
# 0           7                     NaN         NaN        NaN      NaN
# 1           7                     NaN         NaN        NaN      NaN
# 2         NaN    1202 Bottle Brush Ln  Harrisburg         NC    28075
# 3           9  4314 Concord Pointe LN     Concord         NC    28027
# 4           6        948 Tartan Ln NW     Concord         NC    28027
#
#             ...            GPA_2014 GPA_ENG_2014 GPA_Math_2014  \
# 0           ...                 NaN          NaN           NaN
# 1           ...                 NaN          NaN           NaN
# 2           ...                 NaN          NaN           NaN
# 3           ...                 NaN          NaN           NaN
# 4           ...                 NaN          NaN           NaN
#
#   GPA_Science_2014 GPA_SocSci_2014  NumAdvanced_2014 NumAdvanced_ENG_2014  \
# 0              NaN             NaN               NaN                  NaN
# 1              NaN             NaN               NaN                  NaN
# 2              NaN             NaN               NaN                  NaN
# 3              NaN             NaN               NaN                  NaN
# 4              NaN             NaN               NaN                  NaN
#
#   NumAdvanced_Math_2014 NumAdvanced_Science_2014 NumAdvanced_SocSci_2014
# 0                   NaN                      NaN                     NaN
# 1                   NaN                      NaN                     NaN
# 2                   NaN                      NaN                     NaN
# 3                   NaN                      NaN                     NaN
# 4                   NaN                      NaN                     NaN
#
# [5 rows x 344 columns]

# %%
merged.shape
# Out:
# (35435, 344)

# %%
list(merged.columns)
# Out:
# ['External_Student_ID',
#  'Street_2008',
#  'CITY_2008',
#  'STATE_2008',
#  'ZIP_2008',
#  'Grade_2008',
#  'Street_2009',
#  'CITY_2009',
#  'STATE_2009',
#  'ZIP_2009',
#  'Grade_2009',
#  'Street_2010',
#  'CITY_2010',
#  'STATE_2010',
#  'ZIP_2010',
#  'Grade_2010',
#  'Street_2011',
#  'CITY_2011',
#  'STATE_2011',
#  'ZIP_2011',
#  'Grade_2011',
#  'Street_2012',
#  'CITY_2012',
#  'STATE_2012',
#  'ZIP_2012',
#  'Grade_2012',
#  'Street_2013',
#  'CITY_2013',
#  'STATE_2013',
#  'ZIP_2013',
#  'Grade_2013',
#  'Street_2014',
#  'CITY_2014',
#  'STATE_2014',
#  'ZIP_2014',
#  'Grade_2014',
#  'SchoolYear_2008_x',
#  'school_code_2008',
#  'grade_2008',
#  'ethnic_2008',
#  'sex_2008',
#  'swd_2008',
#  'eds_2008',
#  'lep_2008',
#  'daysabs_2008',
#  'exc_abs_2008',
#  'unexc_abs_2008',
#  'times_tardy_2008',
#  'FirstEntryDate_2008',
#  'LastExitDate_2008',
#  'FirstEntry_ReportingYear_2008',
#  'LastExit_ReportingYear_2008',
#  'FirstEntry_Grade_2008',
#  'LastEntry_Grade_2008',
#  'Transferred_Before_EOY_2008',
#  'Grade_repeats_2008',
#  'RepeatedGrades_2008',
#  'RepeatedYears_2008',
#  'TransOut_Before_Grade12_Year_2008',
#  'g8year_2008',
#  'graduate_2008',
#  'grad_year_2008',
#  'Expected_GradYear_2008',
#  'Grad_4yr_2008',
#  'SchoolYear_2009_x',
#  'school_code_2009',
#  'grade_2009',
#  'ethnic_2009',
#  'sex_2009',
#  'swd_2009',
#  'eds_2009',
#  'lep_2009',
#  'daysabs_2009',
#  'exc_abs_2009',
#  'unexc_abs_2009',
#  'times_tardy_2009',
#  'FirstEntryDate_2009',
#  'LastExitDate_2009',
#  'FirstEntry_ReportingYear_2009',
#  'LastExit_ReportingYear_2009',
#  'FirstEntry_Grade_2009',
#  'LastEntry_Grade_2009',
#  'Transferred_Before_EOY_2009',
#  'Grade_repeats_2009',
#  'RepeatedGrades_2009',
#  'RepeatedYears_2009',
#  'TransOut_Before_Grade12_Year_2009',
#  'g8year_2009',
#  'graduate_2009',
#  'grad_year_2009',
#  'Expected_GradYear_2009',
#  'Grad_4yr_2009',
#  'SchoolYear_2010_x',
#  'school_code_2010',
#  'grade_2010',
#  'ethnic_2010',
#  'sex_2010',
#  'swd_2010',
#  'eds_2010',
#  'lep_2010',
#  'daysabs_2010',
#  'exc_abs_2010',
#  'unexc_abs_2010',
#  'times_tardy_2010',
#  'FirstEntryDate_2010',
#  'LastExitDate_2010',
#  'FirstEntry_ReportingYear_2010',
#  'LastExit_ReportingYear_2010',
#  'FirstEntry_Grade_2010',
#  'LastEntry_Grade_2010',
#  'Transferred_Before_EOY_2010',
#  'Grade_repeats_2010',
#  'RepeatedGrades_2010',
#  'RepeatedYears_2010',
#  'TransOut_Before_Grade12_Year_2010',
#  'g8year_2010',
#  'graduate_2010',
#  'grad_year_2010',
#  'Expected_GradYear_2010',
#  'Grad_4yr_2010',
#  'SchoolYear_2011_x',
#  'school_code_2011',
#  'grade_2011',
#  'ethnic_2011',
#  'sex_2011',
#  'swd_2011',
#  'eds_2011',
#  'lep_2011',
#  'daysabs_2011',
#  'exc_abs_2011',
#  'unexc_abs_2011',
#  'times_tardy_2011',
#  'FirstEntryDate_2011',
#  'LastExitDate_2011',
#  'FirstEntry_ReportingYear_2011',
#  'LastExit_ReportingYear_2011',
#  'FirstEntry_Grade_2011',
#  'LastEntry_Grade_2011',
#  'Transferred_Before_EOY_2011',
#  'Grade_repeats_2011',
#  'RepeatedGrades_2011',
#  'RepeatedYears_2011',
#  'TransOut_Before_Grade12_Year_2011',
#  'g8year_2011',
#  'graduate_2011',
#  'grad_year_2011',
#  'Expected_GradYear_2011',
#  'Grad_4yr_2011',
#  'SchoolYear_2012_x',
#  'school_code_2012',
#  'grade_2012',
#  'ethnic_2012',
#  'sex_2012',
#  'swd_2012',
#  'eds_2012',
#  'lep_2012',
#  'daysabs_2012',
#  'exc_abs_2012',
#  'unexc_abs_2012',
#  'times_tardy_2012',
#  'FirstEntryDate_2012',
#  'LastExitDate_2012',
#  'FirstEntry_ReportingYear_2012',
#  'LastExit_ReportingYear_2012',
#  'FirstEntry_Grade_2012',
#  'LastEntry_Grade_2012',
#  'Transferred_Before_EOY_2012',
#  'Grade_repeats_2012',
#  'RepeatedGrades_2012',
#  'RepeatedYears_2012',
#  'TransOut_Before_Grade12_Year_2012',
#  'g8year_2012',
#  'graduate_2012',
#  'grad_year_2012',
#  'Expected_GradYear_2012',
#  'Grad_4yr_2012',
#  'SchoolYear_2013_x',
#  'school_code_2013',
#  'grade_2013',
#  'ethnic_2013',
#  'sex_2013',
#  'swd_2013',
#  'eds_2013',
#  'lep_2013',
#  'daysabs_2013',
#  'exc_abs_2013',
#  'unexc_abs_2013',
#  'times_tardy_2013',
#  'FirstEntryDate_2013',
#  'LastExitDate_2013',
#  'FirstEntry_ReportingYear_2013',
#  'LastExit_ReportingYear_2013',
#  'FirstEntry_Grade_2013',
#  'LastEntry_Grade_2013',
#  'Transferred_Before_EOY_2013',
#  'Grade_repeats_2013',
#  'RepeatedGrades_2013',
#  'RepeatedYears_2013',
#  'TransOut_Before_Grade12_Year_2013',
#  'g8year_2013',
#  'graduate_2013',
#  'grad_year_2013',
#  'Expected_GradYear_2013',
#  'Grad_4yr_2013',
#  'SchoolYear_2014_x',
#  'school_code_2014',
#  'grade_2014',
#  'ethnic_2014',
#  'sex_2014',
#  'swd_2014',
#  'eds_2014',
#  'lep_2014',
#  'daysabs_2014',
#  'exc_abs_2014',
#  'unexc_abs_2014',
#  'times_tardy_2014',
#  'FirstEntryDate_2014',
#  'LastExitDate_2014',
#  'FirstEntry_ReportingYear_2014',
#  'LastExit_ReportingYear_2014',
#  'FirstEntry_Grade_2014',
#  'LastEntry_Grade_2014',
#  'Transferred_Before_EOY_2014',
#  'Grade_repeats_2014',
#  'RepeatedGrades_2014',
#  'RepeatedYears_2014',
#  'TransOut_Before_Grade12_Year_2014',
#  'g8year_2014',
#  'graduate_2014',
#  'grad_year_2014',
#  'Expected_GradYear_2014',
#  'Grad_4yr_2014',
#  'SchoolYear_2008_y',
#  'Num_Marks_2008',
#  'Num_ENG_2008',
#  'Num_Math_2008',
#  'Num_Science_2008',
#  'Num_SocSci_2008',
#  'GPA_2008',
#  'GPA_ENG_2008',
#  'GPA_Math_2008',
#  'GPA_Science_2008',
#  'GPA_SocSci_2008',
#  'NumAdvanced_2008',
#  'NumAdvanced_ENG_2008',
#  'NumAdvanced_Math_2008',
#  'NumAdvanced_Science_2008',
#  'NumAdvanced_SocSci_2008',
#  'SchoolYear_2009_y',
#  'Num_Marks_2009',
#  'Num_ENG_2009',
#  'Num_Math_2009',
#  'Num_Science_2009',
#  'Num_SocSci_2009',
#  'GPA_2009',
#  'GPA_ENG_2009',
#  'GPA_Math_2009',
#  'GPA_Science_2009',
#  'GPA_SocSci_2009',
#  'NumAdvanced_2009',
#  'NumAdvanced_ENG_2009',
#  'NumAdvanced_Math_2009',
#  'NumAdvanced_Science_2009',
#  'NumAdvanced_SocSci_2009',
#  'SchoolYear_2010_y',
#  'Num_Marks_2010',
#  'Num_ENG_2010',
#  'Num_Math_2010',
#  'Num_Science_2010',
#  'Num_SocSci_2010',
#  'GPA_2010',
#  'GPA_ENG_2010',
#  'GPA_Math_2010',
#  'GPA_Science_2010',
#  'GPA_SocSci_2010',
#  'NumAdvanced_2010',
#  'NumAdvanced_ENG_2010',
#  'NumAdvanced_Math_2010',
#  'NumAdvanced_Science_2010',
#  'NumAdvanced_SocSci_2010',
#  'SchoolYear_2011_y',
#  'Num_Marks_2011',
#  'Num_ENG_2011',
#  'Num_Math_2011',
#  'Num_Science_2011',
#  'Num_SocSci_2011',
#  'GPA_2011',
#  'GPA_ENG_2011',
#  'GPA_Math_2011',
#  'GPA_Science_2011',
#  'GPA_SocSci_2011',
#  'NumAdvanced_2011',
#  'NumAdvanced_ENG_2011',
#  'NumAdvanced_Math_2011',
#  'NumAdvanced_Science_2011',
#  'NumAdvanced_SocSci_2011',
#  'SchoolYear_2012_y',
#  'Num_Marks_2012',
#  'Num_ENG_2012',
#  'Num_Math_2012',
#  'Num_Science_2012',
#  'Num_SocSci_2012',
#  'GPA_2012',
#  'GPA_ENG_2012',
#  'GPA_Math_2012',
#  'GPA_Science_2012',
#  'GPA_SocSci_2012',
#  'NumAdvanced_2012',
#  'NumAdvanced_ENG_2012',
#  'NumAdvanced_Math_2012',
#  'NumAdvanced_Science_2012',
#  'NumAdvanced_SocSci_2012',
#  'SchoolYear_2013_y',
#  'Num_Marks_2013',
#  'Num_ENG_2013',
#  'Num_Math_2013',
#  'Num_Science_2013',
#  'Num_SocSci_2013',
#  'GPA_2013',
#  'GPA_ENG_2013',
#  'GPA_Math_2013',
#  'GPA_Science_2013',
#  'GPA_SocSci_2013',
#  'NumAdvanced_2013',
#  'NumAdvanced_ENG_2013',
#  'NumAdvanced_Math_2013',
#  'NumAdvanced_Science_2013',
#  'NumAdvanced_SocSci_2013',
#  'SchoolYear_2014_y',
#  'Num_Marks_2014',
#  'Num_ENG_2014',
#  'Num_Math_2014',
#  'Num_Science_2014',
#  'Num_SocSci_2014',
#  'GPA_2014',
#  'GPA_ENG_2014',
#  'GPA_Math_2014',
#  'GPA_Science_2014',
#  'GPA_SocSci_2014',
#  'NumAdvanced_2014',
#  'NumAdvanced_ENG_2014',
#  'NumAdvanced_Math_2014',
#  'NumAdvanced_Science_2014',
#  'NumAdvanced_SocSci_2014']

# %%
merged.to_csv(path_or_buf='master_2-9-2015.csv', index=False)
